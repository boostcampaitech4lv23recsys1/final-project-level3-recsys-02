# %% [markdown]
# ## DB와 연결하려 했으나 실패

# %%
import psycopg2

db_connect = psycopg2.connect(
        user="tasha",
        password="tasha",
        host="192.168.253.128",
        port=5432,
        database="tasha-progress-server",
        connect_timeout=3
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 3
#       1 import psycopg2
# ----> 3 db_connect = psycopg2.connect(
#       4         user="tasha",
#       5         password="tasha",
#       6         host="192.168.253.128",
#       7         port=5432,
#       8         database="tasha-progress-server",
#       9         connect_timeout=3
#      10 )
#
# File ~/final/.venv/lib/python3.8/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "192.168.253.128", port 5432 failed: timeout expired

# %% [markdown]
# ## import & api test

# %%
import requests
import json
import pandas as pd
from tqdm import tqdm
import itertools
import pickle
import numpy as np

# %%
with open('./username_sample.pkl', 'rb') as f:
	username_list = pickle.load(f)

# %%
url = 'http://ws.audioscrobbler.com/2.0'

params = {
    "method": "user.getrecenttracks",
    "extended": 1,
    "user": "JM",
    "limit": 1,
    "api_key": "1a62f2d4937452d62d7426029e4c9997",
    "format": "json",
}

text = requests.get(url, params).text
texts = pd.DataFrame(json.loads(text)['recenttracks']['track'])

display(texts)
print(text)
# Out:
#                                               artist  \
# 0  {'url': 'https://www.last.fm/music/my+bloody+v...
#
#                                                 date  \
# 0  {'uts': '1108290000', '#text': '13 Feb 2005, 1...
#
#                                    mbid       name  \
# 0  04e30386-e709-4a86-adc7-ca2ff8ed729a  Sometimes
#
#                                                image  \
# 0  [{'size': 'small', '#text': ''}, {'size': 'med...
#
#                                                  url streamable  \
# 0  https://www.last.fm/music/my+bloody+valentine/...          0
#
#                        album loved
# 0  {'mbid': '', '#text': ''}     1
# {"recenttracks":{"track":[{"artist":{"url":"https:\/\/www.last.fm\/music\/my+bloody+valentine","name":"my bloody valentine","image":[{"size":"small","#text":"https:\/\/lastfm.freetls.fastly.net\/i\/u\/34s\/2a96cbd8b46e442fc41c2b86b821562f.png"},{"size":"medium","#text":"https:\/\/lastfm.freetls.fastly.net\/i\/u\/64s\/2a96cbd8b46e442fc41c2b86b821562f.png"},{"size":"large","#text":"https:\/\/lastfm.freetls.fastly.net\/i\/u\/174s\/2a96cbd8b46e442fc41c2b86b821562f.png"},{"size":"extralarge","#text":"https:\/\/lastfm.freetls.fastly.net\/i\/u\/300x300\/2a96cbd8b46e442fc41c2b86b821562f.png"}],"mbid":""},"date":{"uts":"1108290000","#text":"13 Feb 2005, 10:20"},"mbid":"04e30386-e709-4a86-adc7-ca2ff8ed729a","name":"Sometimes","image":[{"size":"small","#text":""},{"size":"medium","#text":""},{"size":"large","#text":""},{"size":"extralarge","#text":""}],"url":"https:\/\/www.last.fm\/music\/my+bloody+valentine\/_\/Sometimes","streamable":"0","album":{"mbid":"","#text":""},"loved":"1"}],"@attr":{"user":"jm","totalPages":"15","page":"1","perPage":"1","total":"15"}}}

# %%
import requests
import json
import pandas as pd
from tqdm import tqdm
import itertools

url = 'http://ws.audioscrobbler.com/2.0'

params = {
    "method": "user.getrecenttracks",
    "extended": 1,
    "user": "",
    "limit": 1,
    "api_key": "1a62f2d4937452d62d7426029e4c9997",
    "format": "json",
}

dataframe_list = []
for i, user in enumerate(tqdm(username_list)):
    params["user"] = user
    params["limit"] = 1
    text = requests.get(url, params).text
    text = json.loads(text)
    text = text['recenttracks']
    track = text['track']
    attr = text['@attr']
    params["limit"] = 200
    for page in range(int(attr['totalPages'])):
        params["page"] = page + 1
        text = requests.get(url, params).text
        texts = pd.DataFrame(json.loads(text)['recenttracks']['track'])
        texts['username'] = user
        texts['user_total'] = attr['total']

        texts['album_mbid'] = texts['album'].apply(lambda x: x['mbid'])
        texts['album_name'] = texts['album'].apply(lambda x: x['#text'])

        # texts['date_uts'] = texts['date'].apply(lambda x: np.NAN if x==np.NAN else x['uts'])
        texts['date_uts'] = texts['date'].apply(lambda x: x['uts'])
        texts['date_string'] = texts['date'].apply(lambda x: x['#text'])

        texts['artist_url'] = texts['artist'].apply(lambda x: x['url'])
        texts['artist_name'] = texts['artist'].apply(lambda x: x['name'])
        texts['artist_mbid'] = texts['artist'].apply(lambda x: x['mbid'])

        texts.drop(columns=['album', 'date', 'artist', 'image'], inplace=True)
        dataframe_list.append(texts)
        break
data_csv = pd.concat(dataframe_list, ignore_index=True)
data_csv.rename({'mbid':'track_mbid', 'name':'track_name', 'url':'track_url'})
data_csv.replace('', np.NaN, inplace=True)
display(data_csv)
# Out:
#  11%|█         | 11/100 [00:12<01:42,  1.15s/it]
#      mbid                                               name  \
# 0     NaN  Requiem in D Minor, K. 626: 4. Offertorium: Do...
# 1     NaN  Requiem in D Minor, K. 626: 3. Sequentia: Lacr...
# 2     NaN  Requiem in D Minor, K. 626: 3. Sequentia: Conf...
# 3     NaN  Requiem in D Minor, K. 626: 3. Sequentia: Reco...
# 4     NaN  Requiem in D Minor, K. 626: 3. Sequentia: Rex ...
# ...   ...                                                ...
# 2395  NaN                                     Sur le drapeau
# 2396  NaN                                     Sur le drapeau
# 2397  NaN                                     Sur le drapeau
# 2398  NaN                                     Sur le drapeau
# 2399  NaN                                     Sur le drapeau
#
#                                                     url streamable loved  \
# 0     https://www.last.fm/music/Wolfgang+Amadeus+Moz...          0     0
# 1     https://www.last.fm/music/Wolfgang+Amadeus+Moz...          0     0
# 2     https://www.last.fm/music/Wolfgang+Amadeus+Moz...          0     0
# 3     https://www.last.fm/music/Wolfgang+Amadeus+Moz...          0     0
# 4     https://www.last.fm/music/Wolfgang+Amadeus+Moz...          0     0
# ...                                                 ...        ...   ...
# 2395  https://www.last.fm/music/Supr%C3%AAme+NTM/_/S...          0     0
# 2396  https://www.last.fm/music/Supr%C3%AAme+NTM/_/S...          0     0
# 2397  https://www.last.fm/music/Supr%C3%AAme+NTM/_/S...          0     0
# 2398  https://www.last.fm/music/Supr%C3%AAme+NTM/_/S...          0     0
# 2399  https://www.last.fm/music/Supr%C3%AAme+NTM/_/S...          0     0
#
#        username user_total album_mbid  \
# 0     cynocauma      29607        NaN
# 1     cynocauma      29607        NaN
# 2     cynocauma      29607        NaN
# 3     cynocauma      29607        NaN
# 4     cynocauma      29607        NaN
# ...         ...        ...        ...
# 2395  cynocauma      29607        NaN
# 2396  cynocauma      29607        NaN
# 2397  cynocauma      29607        NaN
# 2398  cynocauma      29607        NaN
# 2399  cynocauma      29607        NaN
#
#                                         album_name    date_uts  \
# 0                                  Mozart: Requiem  1674264534
# 1                                  Mozart: Requiem  1674264364
# 2                                  Mozart: Requiem  1674264207
# 3                                  Mozart: Requiem  1674263903
# 4                                  Mozart: Requiem  1674263798
# ...                                            ...         ...
# 2395  Sur le drapeau (Extrait du projet 93 Empire)  1674156906
# 2396  Sur le drapeau (Extrait du projet 93 Empire)  1674156707
# 2397  Sur le drapeau (Extrait du projet 93 Empire)  1674156507
# 2398  Sur le drapeau (Extrait du projet 93 Empire)  1674156308
# 2399  Sur le drapeau (Extrait du projet 93 Empire)  1674156108
#
#              date_string                                         artist_url  \
# 0     21 Jan 2023, 01:28  https://www.last.fm/music/Wolfgang+Amadeus+Mozart
# 1     21 Jan 2023, 01:26  https://www.last.fm/music/Wolfgang+Amadeus+Mozart
# 2     21 Jan 2023, 01:23  https://www.last.fm/music/Wolfgang+Amadeus+Mozart
# 3     21 Jan 2023, 01:18  https://www.last.fm/music/Wolfgang+Amadeus+Mozart
# 4     21 Jan 2023, 01:16  https://www.last.fm/music/Wolfgang+Amadeus+Mozart
# ...                  ...                                                ...
# 2395  19 Jan 2023, 19:35         https://www.last.fm/music/Supr%C3%AAme+NTM
# 2396  19 Jan 2023, 19:31         https://www.last.fm/music/Supr%C3%AAme+NTM
# 2397  19 Jan 2023, 19:28         https://www.last.fm/music/Supr%C3%AAme+NTM
# 2398  19 Jan 2023, 19:25         https://www.last.fm/music/Supr%C3%AAme+NTM
# 2399  19 Jan 2023, 19:21         https://www.last.fm/music/Supr%C3%AAme+NTM
#
#                   artist_name  artist_mbid
# 0     Wolfgang Amadeus Mozart          NaN
# 1     Wolfgang Amadeus Mozart          NaN
# 2     Wolfgang Amadeus Mozart          NaN
# 3     Wolfgang Amadeus Mozart          NaN
# 4     Wolfgang Amadeus Mozart          NaN
# ...                       ...          ...
# 2395              Suprême NTM          NaN
# 2396              Suprême NTM          NaN
# 2397              Suprême NTM          NaN
# 2398              Suprême NTM          NaN
# 2399              Suprême NTM          NaN
#
# [2400 rows x 14 columns]

# %% [markdown]
# ## mbid 에 null 이 너무 많음 & user 끼리 중복됨

# %%
data_csv.notna().sum()
# mbid 에는 null 이 많아서 name 으로 대체
# Out:
# mbid           1307
# name           2400
# url            2400
# streamable     2400
# loved          2400
# username       2400
# user_total     2400
# album_mbid     1396
# album_name     2365
# date_uts       2400
# date_string    2400
# artist_url     2400
# artist_name    2400
# artist_mbid       0
# dtype: int64

# %%
from collections import Counter

result = Counter(username_list)
print(result)

for key in result:
    print(key, result[key])

result = Counter(username_list).values()
print(result)
# Out:
# Counter({'erickdsr12': 14, 'cynocauma': 13, 'NovicePlayer': 12, 'leyrey': 10, 'Nouwh': 10, 'Spectrum321146': 10, 'ZombieTeam67': 9, 'BilingualZebra7': 9, 'AetherJoako': 8, 'rataclans': 5})
# cynocauma 13
# AetherJoako 8
# leyrey 10
# NovicePlayer 12
# Nouwh 10
# erickdsr12 14
# ZombieTeam67 9
# BilingualZebra7 9
# rataclans 5
# Spectrum321146 10
# dict_values([13, 8, 10, 12, 10, 14, 9, 9, 5, 10])

# %% [markdown]
# ## iteraction 수집 & 각종 dictionary 들 선언

# %%
import requests
import json
import pandas as pd
from tqdm import tqdm
import itertools

url = 'http://ws.audioscrobbler.com/2.0'

params_inter = {
    "method": "user.getrecenttracks",
    "extended": 1,
    "user": "",
    "limit": 1,
    "api_key": "1a62f2d4937452d62d7426029e4c9997",
    "format": "json",
}

user2id = {}
track2id = {}
album2id = {}
artist2id = {}

track2artist = {}
artist2album = {}

album2track = {}

def push_track2id(str):
    if str not in track2id:
        track2id[str] = len(track2id)

def push_user2id(str):
    if str not in user2id:
        user2id[str] = len(user2id)

def push_album2id(str):
    if str not in album2id:
        album2id[str] = len(album2id)

def push_artist2id(str):
    if str not in artist2id:
        artist2id[str] = len(artist2id)

def push_track2artist(track, artist):
    if track not in track2artist:
        track2artist[track] = artist

def push_artist2album(artist, album):
    if isinstance(album, float) or album == '':
        return
    if artist not in artist2album:
        artist2album[artist] = [album]
    elif album not in artist2album[artist]:
        artist2album[artist].append(album)

def push_album2track(album, track):
    if album not in album2track:
        album2track[album] = [track]
    elif album not in album2track[album]:
        album2track[album].append(album)

for user in username_list:
    push_user2id(user)

# id2item, id2user dict 는 만들기가 까다로움. 업데이트가 까다롭다.

dataframe_list = []
for user, i in tqdm(user2id.items()):
    params_inter["user"] = user
    params_inter["limit"] = 1
    text = requests.get(url, params_inter).text
    text = json.loads(text)
    text = text['recenttracks']
    track = text['track']
    attr = text['@attr']
    params_inter["limit"] = 200
    for page in range(int(attr['totalPages'])):
        params_inter["page"] = page + 1
        text = requests.get(url, params_inter).text
        texts = json.loads(text)['recenttracks']['track']
        texts = pd.DataFrame(texts)
        texts['user_name'] = user
        # texts['user_total'] = attr['total']
        texts['album_name'] = texts['album'].apply(lambda x: x['#text'])
        texts['timestamp_uts'] = texts['date'].apply(lambda x: float('nan') if isinstance(x, float) else x['uts'])
        # texts['date_string'] = texts['date'].apply(lambda x: float('nan') if isinstance(x, float) else x['#text'])
        texts['artist_name'] = texts['artist'].apply(lambda x: x['name'])
        texts['track_name'] = texts['name']

        texts['track_name'].apply(lambda x: push_track2id(x))
        texts['album_name'].apply(lambda x: push_album2id(x))
        texts['artist_name'].apply(lambda x: push_artist2id(x))
        texts.apply(lambda x: push_track2artist(x['name'], x['artist_name']), axis=1)
        texts.apply(lambda x: push_artist2album(x['artist_name'], x['album_name']), axis=1)

        texts.drop(columns=['album', 'date', 'artist', 'image', 'mbid', 'url', 'streamable', 'name'], inplace=True)
        if '@attr' in list(texts.keys()):
            texts.drop(columns=['@attr'], inplace=True)
        
        dataframe_list.append(texts)
        break

data_csv = pd.concat(dataframe_list, ignore_index=True)
data_csv.rename(columns={'name':'track_name'}, inplace=True)
data_csv.replace('', np.NaN, inplace=True)
data_csv = data_csv.astype({
    'track_name':'string',
    'loved':'int8',
    'user_name':'string',
    'album_name':'string',
    'timestamp_uts':'int64',
    'artist_name':'string',
})
display(data_csv)
data_csv.to_csv("interaction_2000.csv", index=False)
# Out:
# 100%|██████████| 10/10 [00:13<00:00,  1.39s/it]
#       loved       user_name  album_name  timestamp_uts  \
# 0         0       cynocauma  The Search     1674687774
# 1         0       cynocauma  The Search     1674687526
# 2         0       cynocauma  The Search     1674687277
# 3         0       cynocauma  The Search     1674687029
# 4         0       cynocauma  The Search     1674686780
# ...     ...             ...         ...            ...
# 1995      0  Spectrum321146      Groove     1674490044
# 1996      0  Spectrum321146      Groove     1674489923
# 1997      0  Spectrum321146      Groove     1674489783
# 1998      0  Spectrum321146      Groove     1674489665
# 1999      0  Spectrum321146      Groove     1674489537
#
#                        artist_name        track_name
# 0                               NF        The Search
# 1                               NF        The Search
# 2                               NF        The Search
# 3                               NF        The Search
# 4                               NF        The Search
# ...                            ...               ...
# 1995  StreamBeats by Harris Heller           Stopgap
# 1996  StreamBeats by Harris Heller        Disco Ball
# 1997  StreamBeats by Harris Heller  Groove All Night
# 1998  StreamBeats by Harris Heller         Rehearsal
# 1999  StreamBeats by Harris Heller        Toodle Loo
#
# [2000 rows x 6 columns]

# %%
data_csv.dtypes
# Out:
# track_name     string
# loved            int8
# username       string
# album_name     string
# date_uts       string
# date_string    string
# artist_name    string
# dtype: object

# %%
data_csv[data_csv.album_name.isnull()].head()
# Out:
#                    track_name loved username album_name    date_uts  \
# 439              Летучая мышь     0   leyrey        NaN  1674500543
# 523            Opening 2 Full     0   leyrey        NaN  1674473847
# 561                I Need Air     0   leyrey        NaN  1674429812
# 569  Man [Blue Madonna, 2018]     0   leyrey        NaN  1674428025
# 576    Звезда по имени солнце     0   leyrey        NaN  1674426397
#
#             date_string          artist_name
# 439  23 Jan 2023, 19:02      Филипп Киркоров
# 523  23 Jan 2023, 11:37           Death Note
# 561  22 Jan 2023, 23:23  Nothing But Thieves
# 569  22 Jan 2023, 22:53                BØRNS
# 576  22 Jan 2023, 22:26         В. Цой, Кино

# %%
print(len(artist2album)) # album 이 없는 아티스트도 존재하는 듯
print(len(artist2id))
# Out:
# 816
# 838

# %%
# temp_list = [user2id, track2id, album2id, artist2id, track2artist]

# with open('dictionary_list_0122.pkl', 'wb') as f:
# 	pickle.dump(temp_list, f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## track_info

# %%
params_track = {
    "method": "track.getInfo",
    "track": "",
    "artist": "",
    "api_key": "1a62f2d4937452d62d7426029e4c9997",
    "autocorrect": 0,
    "format": "json",
}

tag2id = {}

def push_tag2id(tags):
    for tag in tags:
        if tag not in tag2id:
            tag2id[tag] = len(tag2id)

trackInfo_dataframe_list = []
for i, (track, artist) in enumerate(tqdm(track2artist.items())):
    params_track['track'] = track
    params_track['artist'] = artist
    track = requests.get(url, params_track).text
    track = json.loads(track)['track']

    track['artist_name'] = track['artist']['name']
    # if 'mbid' in list(track['artist'].keys()):
    #     track['artist_mbid'] = track['artist'].apply(lambda x: x['mbid'])
    # else:
    #     track['artist_mbid'] = np.nan
    track['artist_url'] = track['artist']['url']

    # track['tag'] = track['toptags'].apply(lambda x: x['tag']) # 태그가 다 없음
    track['tags'] = list(pd.DataFrame(track['toptags']['tag']).apply(lambda x: (x['name']), axis=1))
    # print(track['tag'])
    push_tag2id(track['tags'])

    # track['toptags'].apply(lambda x: push_tag2id(x['tag']), axis=1)
    # track['tag'] = track['toptags'].apply(lambda x: x['tag'] if x != list([]) else np.nan)
    
    if 'album' in list(track.keys()):
        track['album_name'] = track['album']['title']
    #     track['album_url'] = track['album'].apply(lambda x: x['image'][-1]['#text'])
    #     track['album_artist'] = track['album'].apply(lambda x: x['artist'])
    #     track.drop(columns=['album'], inplace=True)
    else:
        track['album_name'] = np.nan
    #     track['album_url'] = np.nan
    #     track['album_artist'] = np.nan

    track = pd.DataFrame([track])
    if 'album' in list(track.keys()):
        track.drop(columns=['album'], inplace=True)
    
    if 'wiki' in list(track.keys()):
        track.drop(columns=['wiki'], inplace=True)

    if 'mbid' in list(track.keys()):
        track.drop(columns=['mbid'], inplace=True)
    track['streamable_text'] = track['streamable'].apply(lambda x: x['#text'])
    track['streamable_fulltrack'] = track['streamable'].apply(lambda x: x['fulltrack'])
    track.drop(columns=['artist', 'streamable', 'toptags'], inplace=True)
    trackInfo_dataframe_list.append(track)

trackInfo_csv = pd.concat(trackInfo_dataframe_list, ignore_index=True)
trackInfo_csv.rename(columns={'name':'track_name', 'tags':'track_tag_list'}, inplace=True)
trackInfo_csv = trackInfo_csv.astype({
    'track_name':'string',
    # 'url':'string',
    'duration':'int32',
    'listeners':'int32',
    'playcount':'int32',
    'artist_name':'string',
    'artist_url':'string',
    'track_tag_list':'object',
    'artist_url':'string',
    'streamable_text':'int8',
    'streamable_fulltrack':'int8'
})
display(trackInfo_csv.head())
trackInfo_csv.to_csv("trackinfo_50.csv", index=False)
# Out:
#   1%|          | 11/1270 [00:02<05:01,  4.17it/s]
#                     track_name  \
# 0                   The Search
# 1                    Le Boeing
# 2  Le rendez-vous au skatepark
# 3                     Superman
# 4                  Vroum vroum
#
#                                                  url  duration  listeners  \
# 0          https://www.last.fm/music/NF/_/The+Search    248000     176807
# 1  https://www.last.fm/music/Oscar+les+vacances/_...    187000         31
# 2  https://www.last.fm/music/Oscar+les+vacances/_...    173000         32
# 3  https://www.last.fm/music/Oscar+les+vacances/_...    160000         57
# 4  https://www.last.fm/music/Oscar+les+vacances/_...    162000         95
#
#    playcount         artist_name  \
# 0    2074521                  NF
# 1        145  Oscar les vacances
# 2        162  Oscar les vacances
# 3        318  Oscar les vacances
# 4        364  Oscar les vacances
#
#                                      artist_url  \
# 0                  https://www.last.fm/music/NF
# 1  https://www.last.fm/music/Oscar+les+vacances
# 2  https://www.last.fm/music/Oscar+les+vacances
# 3  https://www.last.fm/music/Oscar+les+vacances
# 4  https://www.last.fm/music/Oscar+les+vacances
#
#                             track_tag_list  album_name  streamable_text  \
# 0  [Hip-Hop, rap, conscious hip-hop, trap]  The Search                0
# 1                                       []       Vroum                0
# 2                                       []       Vroum                0
# 3                                       []       Vroum                0
# 4                                       []  Vroum - EP                0
#
#    streamable_fulltrack
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %%
trackInfo_csv.dtypes
# Out:
# track_name              string
# url                     string
# duration                 int32
# listeners                int32
# playcount                int32
# artist_name             string
# artist_url              string
# track_tag_list          object
# album_title             string
# streamable_text           int8
# streamable_fulltrack      int8
# dtype: object

# %%
trackInfo_csv.notna().sum() # 수정 후: mbid, title, album, wiki, artist_mbid 는 삭제
# Out:
# track_name              52
# url                     52
# duration                52
# listeners               52
# playcount               52
# artist_name             52
# artist_url              52
# track_tag_list          52
# album_title             48
# streamable_text         52
# streamable_fulltrack    52
# dtype: int64

# %%
(trackInfo_csv['streamable_fulltrack'] == trackInfo_csv['streamable_text']).sum()
# Out:
# 52

# %% [markdown]
# ## album info

# %%
params_album = {
    "method": "album.getInfo",
    "album": "",
    "artist" : "",
    "api_key": "1a62f2d4937452d62d7426029e4c9997",
    "autocorrect": 0,
    "format": "json",
}

albumInfo_dataframe_list = []
for i, (artist, albums) in enumerate(tqdm(artist2album.items())):
    params_album['artist'] = artist
    for album in albums:
        params_album['album'] = album
        album = requests.get(url, params_album).text
        try:
            album = json.loads(album)['album']
        except:
            print(album)
            print(artist, albums, album, params_album)
        
        album['tag'] = album['tags']
        # print(album['image'][-1])
        album['image_url'] = album['image'][-1]['#text']
        # print(album['wiki'])

        try:
            album['published'] = album['wiki']['published']
            # album['summary'] = album['wiki']['summary']
            # album['content'] = album['wiki']['content']
            album = pd.DataFrame([album])
            album.drop(columns = ['wiki'], inplace=True)
        except:
            # album['summary'] = np.nan
            # album['content'] = np.nan
            album = pd.DataFrame([album])

        # display(pd.DataFrame(album['tracks'].item()['track']))
        # album['track'] = list(album['tracks']['track'].apply(lambda x: (x['name'], x['artist']['name'])))
        # print(pd.DataFrame(album['tracks'].item()['track']))
        # print(album['tags'][0])

        # try:
        #     if isinstance(album['tracks'].item()['track'], list):
        #         album['track'] = [list(pd.DataFrame(album['tracks'].item()['track']).apply(lambda x: (x['name'], x['artist']['name']), axis=1))]
        #     else:
        #         album['track'] = [list(pd.DataFrame([album['tracks'].item()['track']]).apply(lambda x: (x['name'], x['artist']['name']), axis=1))]
        # except:
        #     album['track'] = np.nan # album 을 조회했는데 tracks 가 없는 경우..?
        
        try:
            album['tag'] = [list(pd.DataFrame(album['tags'].item()['tag']).apply(lambda x: (x['name']), axis=1))]
        except:
            album['tag'] = np.nan
            break
        albumInfo_dataframe_list.append(album)
        if 'tracks' in list(album.keys()):
            album.drop(columns=['tracks'], inplace=True)

        album.drop(columns=['tags', 'mbid', 'image'], inplace=True)

albumInfo_csv = pd.concat(albumInfo_dataframe_list, ignore_index=True)
albumInfo_csv.rename(columns={'artist':'artist_name', 'name':'album_name'}, inplace=True)
albumInfo_csv.replace('', np.NaN, inplace=True)
albumInfo_csv = albumInfo_csv.astype({
    'artist_name':'string',
    'album_name':'string',
    'image_url':'string',
    'listeners':'int32',
    'playcount':'int32',
    'url':'string',
    'tag':'object',
    'published':'string',
})
display(albumInfo_csv)
albumInfo_csv.to_csv("albumInfo_50.csv", index=False)
# Out:
#   4%|▍         | 31/741 [00:15<06:00,  1.97it/s]
#                 artist_name  playcount  \
# 0                        NF   12490521
# 1                        NF    9924710
# 2                       JVG      75692
# 3   Wolfgang Amadeus Mozart    1670653
# 4                       Bry     107494
# 5                    Gringe     371954
# 6                    Pixies   15549432
# 7              Liana Flores    4888773
# 8                  Don Omar     985682
# 9         Foster the People     101139
# 10        Foster the People    8281481
# 11        Foster the People   47134971
# 12        Foster the People     471859
# 13        Foster the People    5834545
# 14        Foster the People      17777
# 15                Metallica   17474636
# 16                Metallica    4094382
# 17                Metallica    2080063
# 18                Metallica   37570569
# 19                Metallica    4637477
# 20                Metallica    5028697
# 21          Tears for Fears    7150037
# 22        Rex Orange County   14235251
# 23        Rex Orange County    5185797
# 24        Rex Orange County     759302
# 25              Giant Rooks     670637
# 26              David Bowie    9595003
# 27          Phoebe Bridgers   27881120
# 28          Phoebe Bridgers   56851007
# 29                 Maroon 5   10094283
# 30               The Marías    3707542
# 31               The Marías    3396381
# 32              Soda Stereo     886427
# 33              Soda Stereo     881672
# 34              Soda Stereo     735783
# 35             Milky Chance   11311185
# 36             Milky Chance     122406
# 37             Milky Chance     668738
# 38             Milky Chance    1055874
# 39             Milky Chance     117185
# 40                     MGMT   73993505
# 41                Ela Minus     593851
# 42           Blonde Redhead    4436380
# 43                 Dua Lipa   62418552
# 44        Children of Bodom   10144875
# 45               Mr. Bungle      48151
# 46               Wolfmother   19677500
# 47      My Chemical Romance   57333033
# 48      My Chemical Romance     615949
#
#                                                   url  \
# 0             https://www.last.fm/music/NF/The+Search
# 1             https://www.last.fm/music/NF/Perception
# 2         https://www.last.fm/music/JVG/Ikuinen+vappu
# 3   https://www.last.fm/music/Wolfgang+Amadeus+Moz...
# 4                   https://www.last.fm/music/Bry/BRY
# 5        https://www.last.fm/music/Gringe/Enfant+lune
# 6        https://www.last.fm/music/Pixies/Surfer+Rosa
# 7     https://www.last.fm/music/Liana+Flores/recently
# 8     https://www.last.fm/music/Don+Omar/The+Last+Don
# 9   https://www.last.fm/music/Foster+the+People/Th...
# 10  https://www.last.fm/music/Foster+the+People/Su...
# 11  https://www.last.fm/music/Foster+the+People/To...
# 12  https://www.last.fm/music/Foster+the+People/In...
# 13  https://www.last.fm/music/Foster+the+People/Sa...
# 14  https://www.last.fm/music/Foster+the+People/To...
# 15  https://www.last.fm/music/Metallica/...and+Jus...
# 16  https://www.last.fm/music/Metallica/Kill+%27em...
# 17  https://www.last.fm/music/Metallica/Ride+the+L...
# 18      https://www.last.fm/music/Metallica/Metallica
# 19  https://www.last.fm/music/Metallica/Ride+The+L...
# 20  https://www.last.fm/music/Metallica/Master+Of+...
# 21  https://www.last.fm/music/Tears+for+Fears/Song...
# 22   https://www.last.fm/music/Rex+Orange+County/Pony
# 23  https://www.last.fm/music/Rex+Orange+County/Su...
# 24  https://www.last.fm/music/Rex+Orange+County/Ne...
# 25   https://www.last.fm/music/Giant+Rooks/New+Estate
# 26  https://www.last.fm/music/David+Bowie/The+Rise...
# 27  https://www.last.fm/music/Phoebe+Bridgers/Stra...
# 28  https://www.last.fm/music/Phoebe+Bridgers/Puni...
# 29               https://www.last.fm/music/Maroon+5/V
# 30  https://www.last.fm/music/The+Mar%C3%ADas/Supe...
# 31  https://www.last.fm/music/The+Mar%C3%ADas/Supe...
# 32  https://www.last.fm/music/Soda+Stereo/Nada+Per...
# 33  https://www.last.fm/music/Soda+Stereo/Soda+Ste...
# 34  https://www.last.fm/music/Soda+Stereo/Signos+(...
# 35  https://www.last.fm/music/Milky+Chance/Sadnece...
# 36        https://www.last.fm/music/Milky+Chance/Fado
# 37   https://www.last.fm/music/Milky+Chance/Trip+Tape
# 38  https://www.last.fm/music/Milky+Chance/Mind+th...
# 39    https://www.last.fm/music/Milky+Chance/The+Game
# 40  https://www.last.fm/music/MGMT/Oracular+Specta...
# 41  https://www.last.fm/music/Ela+Minus/acts+of+re...
# 42  https://www.last.fm/music/Blonde+Redhead/Melod...
# 43  https://www.last.fm/music/Dua+Lipa/Future+Nost...
# 44  https://www.last.fm/music/Children+of+Bodom/Ar...
# 45  https://www.last.fm/music/Mr.+Bungle/The+Night...
# 46    https://www.last.fm/music/Wolfmother/Wolfmother
# 47  https://www.last.fm/music/My+Chemical+Romance/...
# 48  https://www.last.fm/music/My+Chemical+Romance/...
#
#                                            album_name  listeners  \
# 0                                          The Search     322774
# 1                                          Perception     422252
# 2                                       Ikuinen vappu       7389
# 3                                     Mozart: Requiem     133983
# 4                                                 BRY       5651
# 5                                         Enfant lune      14015
# 6                                         Surfer Rosa     967234
# 7                                            recently     299013
# 8                                        The Last Don     169392
# 9                                    The Things We Do      27799
# 10                                         Supermodel     396231
# 11                                            Torches    2029106
# 12       In The Darkest of Nights, Let the Birds Sing      54704
# 13                                 Sacred Hearts Club     363621
# 14                                          Torches X       4486
# 15                             ...and Justice for All     856095
# 16                          Kill 'em All (Remastered)     236036
# 17           Ride the Lightning (Deluxe / Remastered)     197447
# 18                                          Metallica    1644229
# 19                    Ride The Lightning (Remastered)     272084
# 20                     Master Of Puppets (Remastered)     383723
# 21    Songs From The Big Chair (Super Deluxe Edition)     775304
# 22                                               Pony     538091
# 23                                          Sunflower     463393
# 24                                          New House     105650
# 25                                         New Estate      50050
# 26  The Rise and Fall of Ziggy Stardust and the Sp...     530902
# 27                               Stranger in the Alps     692825
# 28                                           Punisher     723991
# 29                                                  V     822341
# 30                                 Superclean, Vol. I     289871
# 31                                Superclean, Vol. II     236771
# 32                         Nada Personal (Remastered)      60668
# 33                           Soda Stereo (Remastered)      61441
# 34                                Signos (Remastered)      58087
# 35                                       Sadnecessary     747397
# 36                                               Fado      25114
# 37                                          Trip Tape      62743
# 38                                      Mind the Moon      74242
# 39                                           The Game      25263
# 40                               Oracular Spectacular    3015317
# 41                                  acts of rebellion      49982
# 42                   Melody of Certain Damaged Lemons     326691
# 43                                   Future Nostalgia    1172533
# 44                                  Are You Dead Yet?     439908
# 45                           The Night They Came Home       4591
# 46                                         Wolfmother    1272988
# 47                     Three Cheers for Sweet Revenge    1570409
# 48                      The Black Parade: The B-Sides      41261
#
#                                                   tag  \
# 0          [rap, hip-hop, 2019, 2010s, emotional rap]
# 1             [nf, best of 2017, 2017, rap, american]
# 2               [suomirap, 2010s, 2019, pop, finnish]
# 3     [classical, requiem, mozart, choral, conductor]
# 4           [rock, indie, indie rock, irish, ireland]
# 5                           [rap, france, french rap]
# 6   [alternative rock, 1988, indie rock, alternati...
# 7   [comforting, 4, liana flores, acoustic, indie ...
# 8        [reggaeton, don omar, latin, bachata, dance]
# 9   [indie, disco, disco pop, indie pop, alternative]
# 10  [indie, indie rock, indie pop, 2014, alternative]
# 11  [indie pop, 2011, indie, best of 2011, alterna...
# 12      [psychedelic, indie, rock, indie rock, disco]
# 13               [2017, electronic, indie, rock, pop]
# 14  [indie, indie pop, indie rock, alternative, el...
# 15  [thrash metal, progressive metal, metal, heavy...
# 16  [thrash metal, speed metal, metallica, metal, ...
# 17  [thrash metal, heavy metal, metal, hard rock, ...
# 18  [heavy metal, metal, thrash metal, hard rock, ...
# 19  [thrash metal, metal, rock, heavy metal, hard ...
# 20  [thrash metal, metal, heavy metal, metallica, ...
# 21        [80s, new wave, pop, tears for fears, rock]
# 22                  [2019, indie pop, rnb, pop, male]
# 23   [indie pop, indie, sophisti-pop, jazz pop, soul]
# 24         [jazz, indie, chamber pop, rnb, indie pop]
# 25  [laut.fm/dailyvibes, lovethatindiestuff, indie...
# 26  [glam rock, art rock, proto-punk, pop rock, rock]
# 27       [2017, vinyl, indie, indie rock, indie folk]
# 28  [2020, indie rock, indie folk, singer-songwrit...
# 29  [pop, love at first listen, cult, 2014, romantic]
# 30  [indie, indie pop, american, art pop, california]
# 31  [2010s, bedroom pop, chill pop, sophisti-pop, ...
# 32  [rock en español, rock argentino, 1985, rock, ...
# 33  [musica divertida, rock en espanol, rock en es...
# 34  [rock en español, rock argentino, 1986, lounge...
# 35  [indie, indie folk, indie pop, folktronica, 2013]
# 36  [indie, indie rock, reggae, german, singer-son...
# 37  [indie, indie rock, reggae, german, singer-son...
# 38                  [indie, 2010s, 2019, pop, reggae]
# 39                  [2010s, 2019, indie, pop, reggae]
# 40  [electronic, indie, 2008, best of 2008, altern...
# 41   [2020, electronic, frauen und technik, dance, 4]
# 42  [2000, indie rock, 77davez-all-tracks, indie, ...
# 43        [pop, dance-pop, disco, nu-disco, synthpop]
# 44  [melodic death metal, death metal, metal, thra...
# 45  [death metal, thrash metal, thrash, avant-gard...
# 46  [rock, hard rock, stoner rock, australian, alt...
# 47          [rock, alternative, emo, punk, punk rock]
# 48  [rock, alternative, alternative rock, punk roc...
#
#                                             image_url           published
# 0   https://lastfm.freetls.fastly.net/i/u/300x300/...  03 Mar 2022, 14:41
# 1   https://lastfm.freetls.fastly.net/i/u/300x300/...  10 Oct 2022, 04:15
# 2   https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 3   https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 4   https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 5   https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 6   https://lastfm.freetls.fastly.net/i/u/300x300/...  07 Jul 2022, 16:03
# 7   https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 8   https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 9   https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 10  https://lastfm.freetls.fastly.net/i/u/300x300/...  10 Oct 2015, 20:37
# 11  https://lastfm.freetls.fastly.net/i/u/300x300/...  02 Feb 2022, 06:07
# 12  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 13  https://lastfm.freetls.fastly.net/i/u/300x300/...  02 Feb 2022, 15:03
# 14  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 15  https://lastfm.freetls.fastly.net/i/u/300x300/...  12 Dec 2008, 04:04
# 16  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 17  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 18  https://lastfm.freetls.fastly.net/i/u/300x300/...  05 May 2019, 22:36
# 19  https://lastfm.freetls.fastly.net/i/u/300x300/...  04 Apr 2016, 09:26
# 20  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 21  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 22  https://lastfm.freetls.fastly.net/i/u/300x300/...  03 Mar 2022, 22:06
# 23  https://lastfm.freetls.fastly.net/i/u/300x300/...  04 Apr 2022, 21:05
# 24  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 25  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 26  https://lastfm.freetls.fastly.net/i/u/300x300/...  07 Jul 2022, 21:31
# 27  https://lastfm.freetls.fastly.net/i/u/300x300/...  03 Mar 2022, 05:25
# 28  https://lastfm.freetls.fastly.net/i/u/300x300/...  06 Jun 2020, 00:56
# 29  https://lastfm.freetls.fastly.net/i/u/300x300/...  06 Jun 2016, 06:31
# 30  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 31  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 32  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 33  https://lastfm.freetls.fastly.net/i/u/300x300/...  06 Jun 2022, 03:54
# 34  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 35  https://lastfm.freetls.fastly.net/i/u/300x300/...  06 Jun 2020, 13:49
# 36  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 37  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 38  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 39  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 40  https://lastfm.freetls.fastly.net/i/u/300x300/...  11 Nov 2022, 23:14
# 41  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 42  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 43  https://lastfm.freetls.fastly.net/i/u/300x300/...  10 Oct 2022, 10:56
# 44  https://lastfm.freetls.fastly.net/i/u/300x300/...  05 May 2009, 21:18
# 45  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>
# 46  https://lastfm.freetls.fastly.net/i/u/300x300/...  12 Dec 2012, 03:30
# 47  https://lastfm.freetls.fastly.net/i/u/300x300/...  10 Oct 2008, 12:14
# 48  https://lastfm.freetls.fastly.net/i/u/300x300/...                <NA>

# %%
albumInfo_csv.dtypes
# Out:
# artist_name    string
# album_name     string
# image          string
# listeners       int32
# playcount       int32
# url            string
# tag            object
# content        string
# track          object
# published      string
# dtype: object

# %%
albumInfo_csv.notnull().sum()
# Out:
# artist_name    66
# album_name     66
# image          66
# listeners      66
# playcount      66
# url            66
# tag            66
# content        35
# track          64
# published      35
# dtype: int64

# %% [markdown]
# ## userinfo

# %%
params_user = {
    "method": "user.getInfo",
    "user": "",
    "api_key": "1a62f2d4937452d62d7426029e4c9997",
    "format": "json",
}

gender_dict = {'n' : 0}
userInfo_dataframe_list = []
for user, i in tqdm(user2id.items()):
    params_user['user'] = user
    user = requests.get(url, params_user).text
    user = json.loads(user)['user']
    user['image_url'] = user['image'][-1]['#text']
    user['registered_uts'] = user['registered']['unixtime']
    # print(user['gender'])
    user['gender'] = gender_dict[user['gender']]
    user = pd.DataFrame([user])
    user['follower'] = np.nan
    user['following'] = np.nan

    user.drop(columns=['playlists', 'image', 'type', 'artist_count', 'track_count', 'album_count', 'image', 'registered'], inplace=True)
    userInfo_dataframe_list.append(user)

userInfo_csv = pd.concat(userInfo_dataframe_list, ignore_index=True)
userInfo_csv.replace('None', np.NaN, inplace=True)
userInfo_csv.replace('', np.NaN, inplace=True)
userInfo_csv = userInfo_csv.astype({
    'name':'string',
    'age':'int',
    'subscriber':'int',
    'realname':'string',
    'bootstrap':'int',
    'playcount':'int',
    'image_url':'string',
    'realname':'string',
    'registered_uts':'string', # ?
    'country':'string',
    'gender':'int8',
    'url':'string',
})
display(userInfo_csv)
userInfo_csv.to_csv("userInfo_10.csv", index=False)
# Out:
# 100%|██████████| 10/10 [00:02<00:00,  3.90it/s]
#               name  age  subscriber realname  bootstrap  playcount country  \
# 0        cynocauma    0           0     <NA>          0      30021    <NA>
# 1      AetherJoako    0           0  Joaquín          0       7142   Chile
# 2           leyrey    0           0   leyrey          0     118430    <NA>
# 3     NovicePlayer    0           0     <NA>          0      22942    <NA>
# 4            Nouwh    0           0     <NA>          0      51038    <NA>
# 5       erickdsr12    0           0    erick          0     217321  Brazil
# 6     ZombieTeam67    0           0     <NA>          0      83732    <NA>
# 7  BilingualZebra7    0           0     <NA>          0      20626    <NA>
# 8        rataclans    0           0     <NA>          0      17466    <NA>
# 9   Spectrum321146    0           0     <NA>          0      59185    <NA>
#
#    gender                                       url  \
# 0       0        https://www.last.fm/user/cynocauma
# 1       0      https://www.last.fm/user/AetherJoako
# 2       0           https://www.last.fm/user/leyrey
# 3       0     https://www.last.fm/user/NovicePlayer
# 4       0            https://www.last.fm/user/Nouwh
# 5       0       https://www.last.fm/user/erickdsr12
# 6       0     https://www.last.fm/user/ZombieTeam67
# 7       0  https://www.last.fm/user/BilingualZebra7
# 8       0        https://www.last.fm/user/rataclans
# 9       0   https://www.last.fm/user/Spectrum321146
#
#                                            image_url registered_uts  follower  \
# 0                                               <NA>     1645178226       NaN
# 1  https://lastfm.freetls.fastly.net/i/u/300x300/...     1541372926       NaN
# 2  https://lastfm.freetls.fastly.net/i/u/300x300/...     1540131248       NaN
# 3                                               <NA>     1653624752       NaN
# 4  https://lastfm.freetls.fastly.net/i/u/300x300/...     1571770571       NaN
# 5  https://lastfm.freetls.fastly.net/i/u/300x300/...     1427065817       NaN
# 6  https://lastfm.freetls.fastly.net/i/u/300x300/...     1637281617       NaN
# 7                                               <NA>     1641992153       NaN
# 8                                               <NA>     1645507377       NaN
# 9  https://lastfm.freetls.fastly.net/i/u/300x300/...     1597755411       NaN
#
#    following
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN

# %%
userInfo_csv.dtypes
# Out:
# name            string
# age              int64
# subscriber       int64
# realname        string
# bootstrap        int64
# playcount        int64
# artist_count     int64
# playlists        int64
# track_count      int64
# album_count      int64
# image           string
# registered      string
# country         string
# gender          string
# url             string
# type            string
# dtype: object

# %% [markdown]
# ## taginfo

# %%
len(tag2id)
# Out:
# 16

# %%
params_tag = {
    "method": "tag.getInfo",
    "tag": "",
    "api_key": "1a62f2d4937452d62d7426029e4c9997",
    "format": "json",
}

print(tag2id)

tagInfo_dataframe_list = []
for tag, i in tqdm(tag2id.items()):
    params_tag['tag'] = tag
    tag = requests.get(url, params_tag).text
    tag = json.loads(tag)['tag']
    # print(tag.keys())
    # tag['summary'] = tag['wiki']['summary']
    # tag['content'] = tag['wiki']['content']
    tag = pd.DataFrame([tag])
    tag.drop(columns=['wiki'], inplace=True)
    
    tagInfo_dataframe_list.append(tag)

tagInfo_csv = pd.concat(tagInfo_dataframe_list, ignore_index=True)
tagInfo_csv.replace('', np.NaN, inplace=True)
tagInfo_csv = tagInfo_csv.astype({
    'name':'string',
    'total':'int',
    'reach':'int',
})
display(tagInfo_csv)
tagInfo_csv.to_csv("tagInfo.csv", index=False)
# Out:
# {'Hip-Hop': 0, 'rap': 1, 'conscious hip-hop': 2, 'trap': 3, 'Suomirap': 4, '2010s': 5, '2019': 6, 'pop': 7}
# 100%|██████████| 8/8 [00:01<00:00,  5.22it/s]
#                 name    total   reach
# 0            Hip-Hop   891992  129238
# 1                rap   595768  107037
# 2  conscious hip-hop     2723     566
# 3               trap    50140    9260
# 4           Suomirap     6371     349
# 5              2010s    53658    1290
# 6               2019    19725     644
# 7                pop  2023179  229787

# %%
display(tagInfo_csv.dtypes)
tagInfo_csv = tagInfo_csv.astype({
    'name':'string',
    'total':'int',
    'reach':'int',
    'summary':'string',
    'content':'string',
})
display(tagInfo_csv.head())
display(tagInfo_csv.dtypes)
# Out:
# name       string
# total       int64
# reach       int64
# summary    string
# content    string
# dtype: object
#        name    total   reach  \
# 0  Suomirap     6371     349
# 1     2010s    53656    1290
# 2      2019    19725     644
# 3   Hip-Hop   891974  129236
# 4       pop  2023130  229785
#
#                                              summary  \
# 0  Rap from Finland, also check out Suomi Rock. <...
# 1  Music released from 2010 to the end of 2019, a...
# 2  Music released in the year 2019, and non-2019 ...
# 3  Hip-Hop, also spelled Hip Hop or HipHop is a r...
# 4  Pop music is a broad-term for many different t...
#
#                                              content
# 0  Rap from Finland, also check out Suomi Rock. <...
# 1  Music released from 2010 to the end of 2019, a...
# 2  Music released in the year 2019, and non-2019 ...
# 3  Hip-Hop, also spelled Hip Hop or HipHop is a r...
# 4  Pop music is a broad-term for many different t...
# name       string
# total       int64
# reach       int64
# summary    string
# content    string
# dtype: object
